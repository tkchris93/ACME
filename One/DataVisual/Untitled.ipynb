# %%
# %matplotlib notebook

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,1000)
y = 1./x
plt.plot(x,y)
# Out:
# /home/tanner/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: RuntimeWarning: divide by zero encountered in divide
#   from IPython.kernel.zmq import kernelapp as app
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
plt.plot(x,y)
