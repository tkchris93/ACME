# %% [markdown]
# #IDEAS FOR BASIC LAYOUT
# ### Introduction
# - motivation behind using importance sampling
# + talk about the importance coefficient
# + law of large numbers
# + LOTUS - expected value of a function.
# + Gaussian tail example
#
# ### Problem 1 (Baby problem)
# - calculate the probablity of drawing from the tail gamma distribution. (gamma? k: 9, theta = .5)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab

# %%
mean = 0
var = 1

# %%
# %matplotlib notebook
sigma = np.sqrt(var)
x = np.linspace(-10,10,500)
plt.plot(x,mlab.normpdf(x,0,1))
plt.plot(x,mlab.normpdf(x,4,1))
plt.plot([3,3],[0,.5])
# Out:
# <img src="data:image/png;base64,...">

# %%
import scipy.stats as ss

# %%
# Importance Sampling
mean = 4
sigma = 1

h = lambda y : y > 3
f = lambda y : ss.norm(0,1).pdf(y)
g = lambda y : ss.norm(mean,sigma).pdf(y)

# %%
IS_list = []
for n in xrange(5000,505000,5000):
    Y = np.random.normal(loc=mean,scale=sigma,size=n)
    IS = 1./n*np.sum(h(Y)*f(Y)/g(Y))
    IS_list.append(IS)
    #print "done with: " + str(n)
IS_list = np.array(IS_list)

#print "Expected: " + str(IS)
#terms_IS = h(Y)*f(Y)/g(Y)
#print "Var: " + str(np.var(terms_IS))

# %%
# Monte Carlo
MC_list = []
for n in xrange(5000,505000,5000):
    X = np.random.normal(size=n)
    MC = 1./n*np.sum(h(X))    
    MC_list.append(MC)
    #print "done with: " + str(n)
MC_list = np.array(MC_list)
#print "Expected: " + str(MC)
#terms_MC = h(X)
#print "Var: " + str(np.var(terms_MC))

# %%
# truth
truth = 1 - ss.norm(0,1).cdf(3)
print truth
# Out:
# 0.00134989803163

# %%
# %matplotlib nbagg
MC_error = abs(truth - MC_list)
IS_error = abs(truth - IS_list)
x = np.arange(5000,505000,5000)
plt.plot(x,MC_error,color='r',label="Monte Carlo")
plt.plot(x,IS_error,color='b',label="Importance Sampling")
plt.title("Error of Estimations")
plt.xlabel("Number of Sample Points")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
y = np.zeros(size)

# %%
# %matplotlib notebook
plt.scatter(imp_weights,y)
# Out:
# <img src="data:image/png;base64,...">

# %%
# plotting the gamma distribution
# %matplotlib notebook
gamma = ss.gamma(a=9,scale=0.5)
x = np.linspace(0,20,500)
y = gamma.pdf(x)
plt.plot(x,y)
plt.plot(x,ss.gamma(a=10,scale=0.5).pdf(x),color='k',lw=2)
plt.plot(x,mlab.normpdf(x,12,3))
plt.plot(x,ss.gamma(a=12,scale=1).pdf(x))
# Out:
# ...
# <img src="data:image/png;base64,...">

# %%
# Out:
# 0.0020872590491349818

# %%
1 - ss.gamma(a=10,scale=0.5).cdf(11)
# Out:
# 0.0015049321858395803

# %%
# %%time

truth = 1 - ss.gamma(a=9,scale=0.5).cdf(10)

# h(x) = 1 if x > 10
# f(x) = G(9,0.5)
# g(x) = G(12,1)

h = lambda y : y > 10 
f = lambda y : ss.gamma(a=9,scale=0.5).pdf(y)
g = lambda y : ss.gamma(a=12,scale=1).pdf(y)


IS_list = []
for n in xrange(5000,705000,5000):
    Y = np.random.gamma(12,scale=1,size=n)
    IS = 1./n*np.sum(h(Y)*f(Y)/g(Y))
    IS_list.append(IS)
    #print "done with: " + str(n)
IS_list = np.array(IS_list)
IS1_error = abs(truth - IS_list)/truth
# Out:
# CPU times: user 49.9 s, sys: 324 ms, total: 50.2 s
# Wall time: 51.1 s

# %%
# %%time
# h(x) = 1 if x > 10
# f(x) = G(9,0.5)
# g(x) = N(12,3)

h = lambda y : y > 10
f = lambda y : ss.gamma(a=9,scale=0.5).pdf(y)
g = lambda y : ss.norm(loc=12,scale=3).pdf(y)

n = 10**6

IS_list = []
for n in xrange(5000,705000,5000):
    Y = np.random.normal(loc=12,scale=3,size=n)
    IS = 1./n*np.sum(h(Y)*f(Y)/g(Y))
    IS_list.append(IS)
    #print "done with: " + str(n)
IS_list = np.array(IS_list)
IS2_error = abs(truth - IS_list)/truth
# Out:
# CPU times: user 37.4 s, sys: 188 ms, total: 37.6 s
# Wall time: 38.6 s

# %%
# %matplotlib notebook
x = np.arange(5000,705000,5000)
plt.plot(x,IS1_error,color='b')
plt.plot(x,IS2_error,color='r')

z1 = np.polyfit(x,IS1_error,1)
p1 = np.poly1d(z1)
z2 = np.polyfit(x,IS2_error,1)
p2 = np.poly1d(z2)

plt.plot(x,p1(x),color='b')
plt.plot(x,p2(x),color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print np.average(IS1_error)
print np.average(IS2_error)
# Out:
# 0.0040266265204
# 0.00486038499522

# %%
x_hat
# Out:
# array([[ 34.95986064]])

# %%
truth = 1 - ss.gamma(a=9,scale=0.5).cdf(10)

# %%
h = lambda x : x > 10

MC_estimates = []
for n in xrange(5000,505000,5000):
    X = np.random.gamma(9,scale=0.5,size=n)
    MC = 1./n*np.sum(h(X))    
    MC_estimates.append(MC)
MC_estimates = np.array(MC_estimates)

# %%
MC_estimates - truth
# Out:
# array([  5.12740951e-04,  -2.87259049e-04,  -4.20592382e-04,
#          2.62740951e-04,   2.72740951e-04,  -2.87259049e-04,
#         -1.72973335e-04,  -2.62259049e-04,  -1.76147938e-04,
#          3.27409509e-05,   5.81954963e-05,   4.60742842e-05,
#         -2.71874434e-04,   1.27409509e-05,   7.27409509e-05,
#          2.25240951e-04,  -2.51964931e-04,   1.12740951e-04,
#         -3.04852282e-06,  -2.72590491e-05,   5.55980937e-05,
#          7.63773145e-05,   8.66539943e-05,   4.60742842e-05,
#          4.07409509e-05,  -1.03359722e-05,  -1.09481271e-04,
#         -1.58304777e-05,  -3.20866353e-05,   1.06074284e-04,
#         -2.09839694e-04,  -2.18509049e-04,  -1.11501473e-04,
#          1.30388010e-04,   1.87026665e-04,  -1.09481271e-04,
#          9.65247346e-05,  -3.46274702e-05,  -4.62334081e-05,
#         -2.25904913e-06,  -2.38444150e-05,  -1.39640002e-04,
#          1.26694439e-04,  -1.45317764e-05,  -8.72590491e-05,
# ...

# %%
# %matplotlib notebook
plt.plot(x,np.abs(MC_estimates - truth))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %%time
np.random.gamma(9,scale=0.5,size=10**6)
# Out:
# CPU times: user 211 ms, sys: 2 ms, total: 213 ms
# Wall time: 242 ms
# array([ 3.30293946,  7.46365732,  3.10615503, ...,  4.45922363,
#         6.76278175,  2.11568514])

# %%
# %%time
np.random.normal(loc=4,scale=2,size=10**6)
# Out:
# CPU times: user 111 ms, sys: 6 ms, total: 117 ms
# Wall time: 136 ms
# array([ 1.45343988,  6.15837738,  1.74147178, ...,  6.54873828,
#         3.990183  ,  3.98005102])

# %%
h = lambda x : x > 3

n = 10**6
X = np.random.normal(size=n)
MC = 1./n * np.sum(h(X))

print MC
# Out:
# 0.001308

# %%
h = lambda x : x > 3
f = lambda x : ss.norm().pdf(x)
g = lambda x : ss.norm(loc=4,scale=1).pdf(x)
n = 10**6
X = np.random.normal(4,scale=1,size=n)
IS = 1./n * np.sum(h(X)*f(X)/g(X))

print IS
# Out:
# 0.0013492335534

# %%
import scipy.stats as ss
f = lambda x : x > 3
h = lambda x : ss.norm().pdf(x)
g = lambda x : ss.norm(loc=4,scale=1).pdf(x)

# Sample from the N(4,1).
n = 10**7
X = np.random.normal(4,scale=1,size=n)

# Calculate estimate.
print 1./n * np.sum(f(X)*h(X)/g(X))
# Out:
# 0.00134921134631
