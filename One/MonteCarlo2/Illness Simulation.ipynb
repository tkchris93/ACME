# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import random
import matplotlib.cm as cm

# %%
# %matplotlib notebook
plt.imshow(people,cmap = cm.Greys)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
